# %% [markdown]
# # HTTP 動態網頁架構說明
#
#
# * 了解動態網頁的資料爬蟲策略
# * 知道非同步網頁載入機制（Ajax）
# * 學習兩種對應動態網頁爬蟲的的策略

# %% [markdown]
# ## 作業目標
#
# 回答以下問題：
#
# 1. 動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？
# 2. 還記得我們在 ETTODAY 靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來， 試著回答看看原因是什麼？及該如何檢查？

# %% [markdown]
# ### 1. 動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？

# %%
import requests
import re
from bs4 import BeautifulSoup
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://www.newscan.com.tw/all-faq/faq-detail-15.htm'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
content = soup.find("div", attrs={'class':'answer-box'})
a = content.text.split()
for i in range(len(a)-1):
  print(a[i])
# Out:
# 靜態網頁
# 超文件標示語言HyperText
# Markup
# Language，簡稱：HTML，HTML是網站建置的基礎技術，常與CSS與Javascript配合成一個適合觀看的網頁，讓瀏覽器去讀取，一般判斷方式為網頁副檔名為html或htm皆為靜態網頁，靜態網頁的優勢為容易為搜尋引擎所接受，所以很多動態網頁會將動態網頁轉變成靜態方式，就是所謂的【偽靜態網頁】來提高搜尋引擎的友善度達到排名優化的成效。
# 動態網頁
# 動態網頁主要是搭配伺服器與資料庫共同運作，主要是使用大量編譯的地方，如會員功能、購物車、討論區等等..，意思是指可以與網頁做互動編譯的網頁，動態網頁的內容隨著用戶的輸入和互動而有所不同有Perl、PHP、ASP、JSP、ColdFusion等編譯方式，從而對動態網頁的內容進行改變。
# 靜態網頁與動態的區別
# 靜態網頁與動態網頁是可以同時存在一個網站上的，二種語言各有其優勢，靜態網站主要是用於較於簡單，更新的不頻繁的網頁，反之動態網站較適合用於，資料內容較大，更新快速的網頁，讓維護人員可以更方便管理網站，也大幅降低維護成本。

# %% [markdown]
# ### 2. 還記得我們在 ETTODAY 靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來， 試著回答看看原因是什麼？及該如何檢查？

# %% [markdown]
#     => 滑鼠滾動至頁面底部後，網站自動更新加入不同的內容。
#
#     => 使用動態網頁爬蟲技術 抓取資訊內容。

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ettoday.net/news/news-list.htm'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find(class_="part_list_2").find_all('h3'):
    print(d.find(class_="date").text, d.find_all('em')[-1].text, d.find_all('a')[-1].text)
# Out:
# 2019/12/17 07:51 體育 下一個簽約的是柳賢振？　至少6隊競爭藍鳥道奇最積極
# 2019/12/17 07:46 生活 快訊／07：41花蓮規模4.0地震！　最大震度5級
# 2019/12/17 07:33 時尚 精選6雙「經典藍」球鞋，最低2千元就能穿回家
# 2019/12/17 07:29 政治 「下架吳斯懷」發酵！黃復興黨部爆分裂　上萬韓粉「心機加入國民黨」
# 2019/12/17 07:29 政治 1221高雄大遊行「若有韓粉搗亂」　葉元之分析：一定是反串
# 2019/12/17 07:10 影劇 謝和弦小三「無P原裝真面目」被挖出！　粗手腫臉爆全身動刀…驚人黑歷史曝
# 2019/12/17 07:07 社會 七星煤礦大爆炸49名礦工罹難　誤送52具棺材「竟補滿變死52人」
# 2019/12/17 07:05 國際 56歲「大齡女學霸」找不到伴　終遇小學畢業男墜愛河...甜蜜完婚
# 2019/12/17 07:01 旅遊 40年來銷售10萬個　亞都巴賽麗廳消費經典套餐送法式酥芙蕾
# 2019/12/17 07:00 影劇 「職人劇」專門戶李善均演魯蛇檢察官　《檢察官內傳》舌戰鄭麗媛飆戲
# 2019/12/17 07:00 健康 悲劇！最愛「在節日前提分手」星座男Top3　渣雙子排第2：有新的妹了
# 2019/12/17 06:58 財經 勞動部清查張綱維公司結果今出爐　勞長許銘春10點說明
# 2019/12/17 06:51 生活 張綱維爆「掏空遠航22億」藏錢處曝光　編造假債權遭法官打臉
# 2019/12/17 06:44 政治 波特王燒出前兩次大選關鍵　謝震武：2016年周子瑜一站翻盤
# 2019/12/17 06:29 國際 波音宣布1月起停止製造737 Max　兩空難奪346命...停飛9月難挽回
# 2019/12/17 06:10 時尚 年度最狂巨星Lizzo造型盤點　亮片、緊身衣與爆表的愛自己
# 2019/12/17 05:56 社會 板橋黑衣男深夜持刀碎念「北山歡迎你」　隨手割機車坐墊嚇壞路人
# 2019/12/17 05:56 生活 今飆29度周三一早就變天…最低溫時間曝　跨年前有強冷空氣？彭啟明說話了
# 2019/12/17 05:47 國際 貿易戰趨緩帶氣勢！美股道瓊上漲100點　美媒：年底前股市樂觀
# 2019/12/17 01:56 社會 國道火燒車！休旅急煞閃工地　「3車連撞」燒毀淪廢鐵
# 2019/12/17 01:56 國際 警衝入學校毆打逮人…印度公民法抗爭全國擴散　至少6人死亡
# 2019/12/17 01:53 地方 買新透天厝霸氣加蓋「一樓車庫」　被台南市府整排怒拆了！怪手一天挖光
# 2019/12/17 01:52 影劇 姜河那餐廳遇到粉絲「帥氣全買單了」　粉曬合照感動哭：你要幸福一輩子！
# 2019/12/17 01:39 大陸 爸爸送「深海能量石」！女兒3個月狂流鼻血　海關救了她一命
# 2019/12/17 01:27 網搜 濁水溪捕獲「靈性大白蛇」　韓粉驚喜：雲林出總統，2020有救了
# 2019/12/17 01:23 軍武 這款戰機台灣也有！瑞士談判把「F-5戰機」賣回美國：好過放著爛掉
# 2019/12/17 01:12 網搜 手機遺失被撿到警局！女大生衝現場認領「當場解鎖」…滑開警察全愣了
# 2019/12/17 01:07 政治 力拼翻轉深藍大文山！鄭文燦替張銘祐「掛保證」：選民服務一定找的到人
# 2019/12/17 01:07 財經 道瓊大漲200點！美中貿易協議達成後　美股再創新高
# 2019/12/17 00:52 影劇 吳宗憲「高以翔是韓國人害的」！　韓網氣炸…宋讚養拍片救火：別上升台灣全體
# 2019/12/17 00:48 網搜 被馬莎拉蒂撞上！機車男聽「奇葩15字」放他走　網愣住：慘了
# 2019/12/17 00:33 影劇 BL劇《那一天》完結倒數！　項豪廷「6年後髮型」網崩潰：要催眠自己他是帥的
# 2019/12/17 00:15 健康 整合醫療大數據　北醫大首創數據處！攜手東森集團整合平台資源
# 2019/12/17 00:15 國際 納粹「金髮屠夫」無名墳墓　神秘人詭異挖開…屍骨1根沒動就走了
# 2019/12/17 00:05 時尚 阿灶伯羊肉湯、私房麻糬鬆餅　宜蘭2019新進榜美食你吃過了嗎？
# 2019/12/17 00:02 政治 蔡英文狂丟7邦交國　馬英九：讓台灣產生「亡國感」
# 2019/12/16 23:59 遊戲 2020台北電玩展INDIE GAME AWARD　揭曉11國30款入圍遊戲
# 2019/12/16 23:55 政治 蔡英文讚波特王真民主！綠營子弟兵半年前才罵他「有損城市格調」
# 2019/12/16 23:49 地方 藍軍團結、詹江村臉書PO文支持　陳根德後勢看好
# 2019/12/16 23:45 影劇 胡歌被爆耍流氓「對4字女星動手動腳」　公司回應怒了：嚴重侵犯！
# 2019/12/16 23:44 影劇 李準一退伍就接棒女友節目！　「交往2年依然熱戀ING」韓網讚翻
# 2019/12/16 23:36 軍武 烏克蘭批准中國買下空軍「動力沙皇」　美國阻「馬達西奇公司」收購案失敗
# 2019/12/16 23:35 影劇 鄭人碩「3電影霸榜」登年度片王　數量居亞洲男星之冠！
# 2019/12/16 23:35 生活 錄下正妹練有氧！噁男被解約辯「不是癡漢」...怒告健身房竟獲賠6千
# 2019/12/16 23:33 寵物動物 飯店歡度結婚一周年…夫妻卻遭羞辱式驅離　原因出在他們帶的狗
# 2019/12/16 23:30 財經 為大聯大收購案重披戰袍　文曄董娘感性獨白：從沒想過要打這一仗
# 2019/12/16 23:27 社會 台南水泥車猛衝600m！輾撞7車釀5傷…男騎士捲入車底「卡輪胎」慘死
# 2019/12/16 23:20 影劇 姜丹尼爾要求：關閉《101》第二季討論區　律師心酸揭「憂鬱症活動中斷」原因
# 2019/12/16 23:17 地方 我們夫妻都是議員！　蘇志強宣告「1220遞補就任桃園市議員」
# 2019/12/16 23:12 地方 斗六七品火鍋低調愛心　邀育幼院童享用聖誕晚餐送禮物
# 2019/12/16 23:09 國際 澳洲「引火回燒」抗野火反失控　預測熱浪將打破50.7度紀錄
# 2019/12/16 23:09 影劇 許光漢《想見你》帥樣狂撩粉！施柏宇喊話破3：下麵給大家吃
# 2019/12/16 23:07 政治  斷開藍綠鬆綁　于美人：宋楚瑜當總統會讓台灣人最放心
# 2019/12/16 23:00 時尚 王心恬砸7位數老本　創香氛牌校長兼撞鐘
# 2019/12/16 22:52 影劇 《多情》渣男潘柏希被網友轟去死！他其實是法律系高材生
# 2019/12/16 22:43 影劇 徐若瑄和日本女星鬧不合！　10年後製作人鬆口洩真相…網氣炸：把台灣人當壞人
# 2019/12/16 22:39 政治 政府不能靠稅收…張善政喊「停砍軍公教年金」　提高基金投資報酬率
# 2019/12/16 22:35 影劇 高爾宣深夜突PO「告別作」！　歌詞洩爆紅痛苦「我好累」：內在生了病
# 2019/12/16 22:35 國際 台灣解鎖荷蘭「青年度假打工簽證」　明年4月正式生效
# 2019/12/16 22:34 地方 高雄一德夜市熄燈！上百攤商集結抗議喊「罷免韓國瑜」...大批警舉牌警告
# 2019/12/16 22:32 影劇 被爆「恩愛完甩了余函彌」　王家梁一臉無奈還原交往內幕
# 2019/12/16 22:23 寵物動物 汪得到護目鏡當聖誕禮物　第一次戴去玩雪…牠差點沒樂瘋了
# 2019/12/16 22:23 地方 台中驚傳瓦斯外洩！全家人一氧化碳中毒　12歲男童一度斷氣
# 2019/12/16 22:22 社會 影／中和人孔蓋氣爆「噴飛6層樓」！2工人遭砸送醫…驚悚3秒曝光
# 2019/12/16 22:21 影劇 韓媒爆「BTS準備告公司」7天後道歉了　主播改口：訴訟可能性很低
# 2019/12/16 22:14 政治 宋楚瑜霸氣挺波特王　「不叫蔡英文總統要叫什麼？」
# 2019/12/16 22:12 時尚 長輩最夢幻新年禮！　大甲媽祖 Ｘ 金高58「光明燈」聯名酒款保佑上市
# 2019/12/16 22:12 房產雲 桃園市2020地價調整通過　「地王」寶座14年都是老地段
# 2019/12/16 22:10 時尚 日本風靡超萌「整人飯糰」！咬下竟是罪惡草莓蛋糕　網：好想吃
# 2019/12/16 22:08 旅遊 蘇花改通車加秋冬補助延長　瑞穗春天推出平日買一晚送一晚
# 2019/12/16 22:03 影劇 出道12年最大尺度！蕭敬騰脫光「私密淋浴畫面」曝光...性感炸
# 2019/12/16 22:01 財經 鴻海再加碼27億元　展現投資威州決心
# 2019/12/16 22:01 健康 生產事故救濟報告曝：新生兒、孕產婦死亡率升　衛福部擬建周產期醫療網
# 2019/12/16 21:54 社會 快訊／台中驚傳一氧化碳中毒！12歲男童無呼吸心跳　4人送醫
# 2019/12/16 21:54 生活 遠東停飛衝擊…金門縣長率隊見星宇求支援！　星宇航空正式回應了
# 2019/12/16 21:54 大陸 香港示威超半年「各行業無一倖免」！TVB將裁員350人...年底前通知員工
# 2019/12/16 21:54 寵物動物 重要談判被打斷！　貓老大出「無影腳」趕走掃地機器人
# 2019/12/16 21:47 國際 737MAX年底復飛無望　波音開會討論減產或停止生產線
# 2019/12/16 21:46 社會 女友墮胎子宮大出血！渣男求婚失敗「舉槍性侵」…超慘下場出爐
# 2019/12/16 21:40 地方 2019苗栗音樂佳餚節　搖滾天團八三夭領銜飆音浪
# 2019/12/16 21:39 影劇 波特王合體蔡英文遭解約！　廣告小妹曝「責任在祖國合作方」：沒誠實面對現況
# 2019/12/16 21:36 地方 第三屆「一星衣益 」公益活動大江展開　3880件義賣商品歡迎購
# 2019/12/16 21:35 政治 快訊／再度同框韓國瑜？　館長：韓辦邀約直播「我答應了」
# 2019/12/16 21:34 生活 男玩水上甜甜圈遭甩飛！空中2m墜海「重擊頸椎」　當場四肢癱瘓
# 2019/12/16 21:33 地方 台南智慧綠能科學城啟用　陳其邁：北林口、南沙崙打造台灣綠金聚落
# 2019/12/16 21:32 影劇 楊晨熙：太早成家無法享受青春！　「不怕對象跑掉」：我條件好
# 2019/12/16 21:32 國際 貿易戰「進入颱風眼」　美銀美林：美2020大選後再升級
# 2019/12/16 21:27 健康 壓力山大怎辦！醫揭「6妙招」負能量全空…睡飽真的超重要
# 2019/12/16 21:26 影劇 范瑋琪解答「梁靜茹離婚爆料」：不是我說的！　被追問到底誰講…無奈回應
# 2019/12/16 21:25 地方 台南福利地圖APP　讓社褔地點e指通
# 2019/12/16 21:23 影劇 等了33年！阿湯哥《捍衛戰士2》「親駕大黃蜂」衝上雲霄　熱血傳承麥爾斯泰勒
# 2019/12/16 21:14 地方 台南立人國小新建幼兒園工程8124萬　陳亭妃向教育部爭取成功
# 2019/12/16 21:10 時尚 單身一輩子也沒關係的3大星座　水瓶一個人也能自得其樂
# 2019/12/16 21:06 寵物動物 這是恐龍！農場牛隻接連消失　5.1公尺長巨鱷是凶手
# 2019/12/16 21:03 軍武 解放軍002航母可能命名「湖南艦」　傳月底將舉行成軍典禮
# 2019/12/16 21:02 軍武 美軍新型自走砲XM1299照片曝光　9公尺超長砲管
# 2019/12/16 21:00 地方 新建案佔用都市計畫道路用地　台南市政府施以公權力拆除了
# 2019/12/16 20:57 地方 全台首創智慧停車雲端數據平台啟用　黃偉哲：提供有感的智慧停車服務
# 2019/12/16 20:52 地方 台南數位文創園區6週年　黃偉哲承諾市府扮演青年創業推手
# 2019/12/16 20:52 影劇 2019年IG追蹤數最多韓星出爐！BTS排第四　前六名「BLACKPINK包辦五位」
